# %% [markdown]
# <a href="https://colab.research.google.com/github/sathundorn/Statistical-Learning-Labs1/blob/main/229351_LAB01_670510773.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ปฏิบัติการครั้งที่ 1 กระบวนวิชา 229351 Statistical Learning for Data Science
#
# คำชี้แจง
#
# 1. ให้เริ่มทำปฏิบัติการจาก colab notebook ที่กำหนดให้ **เมื่อเสร็จแล้วให้ทำการ share** จากนั้นส่ง link มาใน mango canvas
#
# ในขั้นตอนแรก ขอให้ download ไฟล์ที่
#
# http://donlapark.pages.dev/229351/data/housing.csv

# %%
import pandas as pd #dataframes
import numpy as np #matrices
import matplotlib.pyplot as plt #for plotting

# %matplotlib inline

# !wget http://donlapark.pages.dev/229351/data/housing.csv

housing = pd.read_csv("housing.csv")

housing.head(10)
# Out:
# --2025-06-26 02:05:02--  http://donlapark.pages.dev/229351/data/housing.csv
# Resolving donlapark.pages.dev (donlapark.pages.dev)... 172.66.47.56, 172.66.44.200, 2606:4700:310c::ac42:2f38, ...
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|172.66.47.56|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://donlapark.pages.dev/229351/data/housing.csv [following]
# --2025-06-26 02:05:02--  https://donlapark.pages.dev/229351/data/housing.csv
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|172.66.47.56|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1423529 (1.4M) [text/csv]
# Saving to: ‘housing.csv’
#
# housing.csv         100%[===================>]   1.36M  --.-KB/s    in 0.06s
#
# 2025-06-26 02:05:03 (21.8 MB/s) - ‘housing.csv’ saved [1423529/1423529]
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY

# %%
housing = pd.read_csv("housing.csv")

# %%
housing.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY

# %% [markdown]
# ## Basic data exploration

# %%
housing.shape #ดูแถว
# Out:
# (20640, 10)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Which variable has missing data?

# %%
housing = housing.dropna()

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563700
# 50%        435.000000   1166.000000    409.000000       3.536500
# 75%        647.000000   1722.000000    604.000000       4.744000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20433.000000
# mean        206864.413155
# std         115435.667099
# min          14999.000000
# 25%         119500.000000
# 50%         179700.000000
# 75%         264700.000000
# max         500001.000000

# %% [markdown]
# ## Exercise 1
#
# 1. Download ไฟล์ข้อมูลที่
#   http://donlapark.pages.dev/229351/data/Advertising.csv
#   ซึ่งเป็นข้อมูลของผลการขายสินค้าอย่างหนึ่ง (Sales) กับการโฆษณาผ่านทาง TV, Radio, Newspaper
# 2. สร้าง dataframe ชื่อว่า **Ads** โดยใช้ข้อมูลชุดนี้
# 3. ดูข้อมูล 5 แถวแรกของ `Ads`
# 4. ตรวจสอบว่ามีข้อมูลที่หายไปหรือไม่
# 5. แสดงค่าสถิติพรรณนา (Descriptive statistics) ของตัวแปรต่างๆ

# %%
# code here
import pandas as pd #dataframes
import numpy as np #matrices
import matplotlib.pyplot as plt #for plotting

# %matplotlib inline

# !wget http://donlapark.pages.dev/229351/data/Advertising.csv
# Out:
# --2025-06-26 02:47:33--  http://donlapark.pages.dev/229351/data/Advertising.csv
# Resolving donlapark.pages.dev (donlapark.pages.dev)... 172.66.47.56, 172.66.44.200, 2606:4700:310c::ac42:2cc8, ...
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|172.66.47.56|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://donlapark.pages.dev/229351/data/Advertising.csv [following]
# --2025-06-26 02:47:33--  https://donlapark.pages.dev/229351/data/Advertising.csv
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|172.66.47.56|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3870 (3.8K) [text/csv]
# Saving to: ‘Advertising.csv.2’
#
# Advertising.csv.2   100%[===================>]   3.78K  --.-KB/s    in 0s
#
# 2025-06-26 02:47:33 (37.7 MB/s) - ‘Advertising.csv.2’ saved [3870/3870]

# %%
Ads = pd.read_csv("Advertising.csv") #สร้าง data frame

# %%
Ads.head(5) #ดู 5 แถวแรก
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
Ads.shape
# Out:
# (200, 4)

# %%
Ads.info() #ตรวจสอบข้อมูล
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
Ads = Ads.dropna()

# %%
Ads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
Ads.describe() #แสดงค่าสถิติพรรณนา
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# Your answers here:

# %% [markdown]
# ## Calling, indexing & modifying dataframes

# %%
# calling a column

housing['ocean_proximity']
# Out:
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY
#            ...
# 20635      INLAND
# 20636      INLAND
# 20637      INLAND
# 20638      INLAND
# 20639      INLAND
# Name: ocean_proximity, Length: 20640, dtype: object

# %% [markdown]
# `ocean_proximity` is categorical. Let's count its values.

# %%
housing["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
housing[["longitude", "latitude", "housing_median_age"]]

# %%
housing.iloc[1:4]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY

# %% [markdown]
# ## Basic statistics of a variable

# %%
print("Mean: ",housing["total_rooms"].mean())
print("Standard deviation: ",housing["total_rooms"].std())
print("Maximum: ",housing["total_rooms"].max())
print("Minimum: ",housing["total_rooms"].min())

# %%
housing[housing["total_bedrooms"] == 200 ]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 364      -122.14     37.75                33.0       1334.0           200.0
# 429      -122.28     37.88                52.0       1193.0           200.0
# 625      -122.17     37.71                38.0        890.0           200.0
# 769      -122.09     37.65                35.0       1184.0           200.0
# 1801     -122.35     37.92                36.0        921.0           200.0
# 3284     -122.79     39.08                23.0        952.0           200.0
# 3420     -118.42     34.28                35.0        822.0           200.0
# 4321     -118.35     34.08                52.0       1003.0           200.0
# 4421     -118.26     34.07                52.0        830.0           200.0
# 5096     -118.30     33.97                42.0        944.0           200.0
# 5224     -118.25     33.95                25.0        764.0           200.0
# 5245     -118.43     34.09                27.0       1613.0           200.0
# 6260     -117.95     34.04                36.0       1044.0           200.0
# 7530     -118.23     33.91                34.0        789.0           200.0
# 9850     -121.89     36.60                19.0        656.0           200.0
# 13268    -117.66     34.09                26.0       1151.0           200.0
# 13390    -117.58     34.09                27.0        754.0           200.0
# 14601    -117.16     32.81                35.0       1213.0           200.0
# 16247    -121.27     37.98                43.0       1005.0           200.0
# 16371    -121.30     38.03                13.0       1014.0           200.0
# 20399    -118.86     34.22                22.0       1230.0           200.0
#
#        population  households  median_income  median_house_value  \
# 364         579.0       202.0         6.8323            255900.0
# 429         506.0       207.0         4.1912            254500.0
# 625         481.0       198.0         3.2440            179800.0
# 769         572.0       194.0         4.7143            193800.0
# 1801        585.0       236.0         1.9224             94000.0
# 3284        321.0       128.0         1.5208             89000.0
# 3420       1197.0       203.0         3.2865            133300.0
# 4321        514.0       204.0         3.8472            395700.0
# 4421        701.0       189.0         2.7625            232100.0
# 5096        567.0       190.0         2.6311            124100.0
# 5224        801.0       220.0         1.1384            100000.0
# 5245        497.0       197.0         7.9835            500001.0
# 6260        982.0       205.0         4.7679            153900.0
# 7530       1041.0       191.0         3.1190             90300.0
# 9850        248.0       173.0         1.2656            500000.0
# 13268       593.0       188.0         3.6667            166300.0
# 13390       746.0       185.0         1.9531            100800.0
# 14601       532.0       181.0         3.6806            172400.0
# 16247       492.0       172.0         2.6812             72800.0
# 16371       712.0       197.0         3.1471            102800.0
# 20399       673.0       195.0         6.2708            251400.0
#
#       ocean_proximity
# 364          NEAR BAY
# 429          NEAR BAY
# 625          NEAR BAY
# 769          NEAR BAY
# 1801         NEAR BAY
# 3284           INLAND
# 3420        <1H OCEAN
# 4321        <1H OCEAN
# 4421        <1H OCEAN
# 5096        <1H OCEAN
# 5224        <1H OCEAN
# 5245        <1H OCEAN
# 6260        <1H OCEAN
# 7530        <1H OCEAN
# 9850        <1H OCEAN
# 13268          INLAND
# 13390          INLAND
# 14601      NEAR OCEAN
# 16247          INLAND
# 16371          INLAND
# 20399       <1H OCEAN

# %%
housing[["longitude", "latitude", "housing_median_age"]]
# Out:
#        longitude  latitude  housing_median_age
# 0        -122.23     37.88                41.0
# 1        -122.22     37.86                21.0
# 2        -122.24     37.85                52.0
# 3        -122.25     37.85                52.0
# 4        -122.25     37.85                52.0
# ...          ...       ...                 ...
# 20635    -121.09     39.48                25.0
# 20636    -121.21     39.49                18.0
# 20637    -121.22     39.43                17.0
# 20638    -121.32     39.43                18.0
# 20639    -121.24     39.37                16.0
#
# [20640 rows x 3 columns]

# %%
housing.loc[0]
# Out:
# longitude              -122.23
# latitude                 37.88
# housing_median_age        41.0
# total_rooms              880.0
# total_bedrooms           129.0
# population               322.0
# households               126.0
# median_income           8.3252
# median_house_value    452600.0
# ocean_proximity       NEAR BAY
# Name: 0, dtype: object

# %% [markdown]
# ## Extracting a subset of dataframe

# %%
housing.loc[1:3, ["longitude","latitude"]]
# Out:
#    longitude  latitude
# 1    -122.22     37.86
# 2    -122.24     37.85
# 3    -122.25     37.85

# %%
housing.iloc[2:5,:]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ## Selecting rows based on conditions

# %%
housing[housing['latitude']>=40]

# %%
housing[(housing['longitude']>-122) & (housing['latitude']>=40)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1102     -121.54     40.06                17.0        858.0           262.0
# 3345     -121.11     41.07                26.0       1707.0           308.0
# 3346     -120.96     41.12                29.0        779.0           136.0
# 3347     -121.07     40.85                17.0        976.0           202.0
# 3348     -120.38     40.98                27.0        777.0           185.0
# ...          ...       ...                 ...          ...             ...
# 18823    -121.62     41.78                40.0       3272.0           663.0
# 18824    -121.93     41.86                28.0       4225.0           835.0
# 18858    -121.76     41.50                31.0        602.0           153.0
# 19735    -121.80     40.34                26.0       4815.0           910.0
# 19736    -121.78     40.12                14.0        388.0           108.0
#
#        population  households  median_income  median_house_value  \
# 1102         47.0        27.0         2.4028             67500.0
# 3345        761.0       250.0         2.7188             48100.0
# 3346        364.0       123.0         2.5000             59200.0
# 3347        511.0       175.0         3.6641             80800.0
# 3348        318.0       115.0         1.6833             40000.0
# ...           ...         ...            ...                 ...
# 18823      1467.0       553.0         1.7885             43500.0
# 18824      1908.0       686.0         1.7400             44000.0
# 18858       112.0        47.0         1.0667             34200.0
# 19735      1341.0       539.0         2.8810             79800.0
# 19736        35.0        17.0         6.1359            106300.0
#
#       ocean_proximity
# 1102           INLAND
# 3345           INLAND
# 3346           INLAND
# 3347           INLAND
# 3348           INLAND
# ...               ...
# 18823          INLAND
# 18824          INLAND
# 18858          INLAND
# 19735          INLAND
# 19736          INLAND
#
# [67 rows x 10 columns]

# %% [markdown]
# ## Exercise 2
#
# ในข้อต่อไปนี้ ให้นับแถวและคอลัมน์เริ่มจาก 0
# 1. แสดงค่าสูงสุดของข้อมูลที่อยู่ในแถวที่ 200-400 ของตัวแปร `total_bedrooms`
# 2. แสดง 3 คอลัมน์สุดท้ายของพื้นที่ที่มีจำนวนห้องนอน (`total_bedrooms`) มากกว่า 900 ห้อง

# %%
# code here
housing.loc[200:400,["total_bedrooms"]].max()
# Out:
# total_bedrooms    2048.0
# dtype: float64

# %%
n_housing = housing[(housing['total_bedrooms'] > 900)]

# %%
n_housing.iloc[-3:,:]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20569    -121.76     38.66                17.0       5320.0           984.0
# 20603    -121.54     39.13                18.0       4289.0          1021.0
# 20629    -121.39     39.12                28.0      10035.0          1856.0
#
#        population  households  median_income  median_house_value  \
# 20569      2866.0       928.0         4.1997            133400.0
# 20603      2707.0       939.0         1.3375             59600.0
# 20629      6912.0      1818.0         2.0943            108300.0
#
#       ocean_proximity
# 20569          INLAND
# 20603          INLAND
# 20629          INLAND

# %% [markdown]
# ## Plotting

# %%
housing.hist(bins=20, figsize=(15,15))
plt.show()

# %%
housing.head(3)

# %%
housing.plot.scatter(x="longitude", y="latitude");

# %%
housing.plot.scatter(x="longitude", y="latitude", alpha=0.1)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
corr_matrix = housing.iloc[:, :-1].corr()

corr_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# housing_median_age       -0.320451   -0.296244   -0.302916      -0.119034
# total_rooms               0.930380    0.857126    0.918484       0.198050
# total_bedrooms            1.000000    0.877747    0.979728      -0.007723
# population                0.877747    1.000000    0.907222       0.004834
# households                0.979728    0.907222    1.000000       0.013033
# median_income            -0.007723    0.004834    0.013033       1.000000
# median_house_value        0.049686   -0.024650    0.065843       0.688075
#
#                     median_house_value
# longitude                    -0.045967
# latitude                     -0.144160
# housing_median_age            0.105623
# total_rooms                   0.134153
# total_bedrooms                0.049686
# population                   -0.024650
# households                    0.065843
# median_income                 0.688075
# median_house_value            1.000000

# %% [markdown]
# ### Grouping
#
# พิจารณา Anscombe dataset ข้างล่างนี้

# %%
import seaborn as sns

df = sns.load_dataset('anscombe')

# %%
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
groups = df.groupby('dataset')

groups

# %%
groups.get_group('I')
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
groups.mean()
# Out:
#            x         y
# dataset
# I        9.0  7.500909
# II       9.0  7.500909
# III      9.0  7.500000
# IV       9.0  7.500909

# %% [markdown]
# ## Exercise 3
#
# 1. คำนวณค่า mean, standard deviation และ correlation matrix ของแต่ละกลุ่ม
# 2. สร้าง scatter plot ของแต่ละกลุ่มด้วย `groups.plot.scatter(...)`
# 3. จากข้อ 1 และข้อ 2 จงบอกว่าการศึกษาค่า summary statistics (mean, s.d., correlation) อย่างเดียวเพียงพอกับการศึกษาข้อมูลชุดหนึ่งหรือไม่ เพราะเหตุใด

# %%
print(groups.mean())
print(groups.std())
print(groups.corr())
# Out:
#            x         y
# dataset
# I        9.0  7.500909
# II       9.0  7.500909
# III      9.0  7.500000
# IV       9.0  7.500909
#                 x         y
# dataset
# I        3.316625  2.031568
# II       3.316625  2.031657
# III      3.316625  2.030424
# IV       3.316625  2.030579
#                   x         y
# dataset
# I       x  1.000000  0.816421
#         y  0.816421  1.000000
# II      x  1.000000  0.816237
#         y  0.816237  1.000000
# III     x  1.000000  0.816287
#         y  0.816287  1.000000
# IV      x  1.000000  0.816521
#         y  0.816521  1.000000

# %%
groups = df.groupby('dataset')

groups

# %%
groups.get_group('III')
# Out:
#    dataset     x      y
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73

# %%
groups.plot.scatter(x = "x",y = "y")
# Out:
# dataset
# I      Axes(0.125,0.11;0.775x0.77)
# II     Axes(0.125,0.11;0.775x0.77)
# III    Axes(0.125,0.11;0.775x0.77)
# IV     Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# จากการศึกษาข้อ1 และข้อ2 การศึกษาจาก summary statistics อย่างเดียวไม่เพียงพอ เพราะเราได้เห็นการกระจายของข้อมูล ความสัมพันธ์ของข้อมูล แต่ไม่ได้เห็นลักษณะการแจกแจงของข้อมูล
#
# ---
