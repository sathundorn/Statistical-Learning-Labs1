# %% [markdown]
# <a href="https://colab.research.google.com/github/sathundorn/Statistical-Learning-Labs1/blob/main/670510773_Lab04_Naive_Bayes_Grid_and_Random_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Statistical Learning for Data Science 2 (229352)
# #### Instructor: Donlapark Ponnoprat
#
# #### [Course website](https://donlapark.pages.dev/229352/)
#
# ## Lab #4

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

from scipy.stats import uniform

# %%
train = fetch_20newsgroups(subset='train')
test = fetch_20newsgroups(subset='test')

Xtrain = train.data[:3000]
ytrain = train.target[:3000]
Xtest = test.data[:500]
ytest = test.target[:500]

print("X:", len(Xtest))
print("y:", len(ytest))
# Out:
# X: 500
# y: 500

# %% [markdown]
# ### Naive Bayes [(Documentation)](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html)

# %%
pipline = Pipeline([
    ('vect', TfidfVectorizer()),
    ('nb', MultinomialNB())
])

# %% [markdown]
# ### Random Search Cross-Validation [(Documentation)](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html)
#
# ### Uniform distribution in `Scipy` [(Documentation)](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.uniform.html)

# %%
parameter = {'nb__alpha': uniform(loc=0, scale = 10)}
clf = RandomizedSearchCV(pipline, parameter, n_iter=7)
clf.fit(Xtrain, ytrain)
# Out:
# RandomizedSearchCV(estimator=Pipeline(steps=[('vect', TfidfVectorizer()),
#                                              ('nb', MultinomialNB())]),
#                    n_iter=7,
#                    param_distributions={'nb__alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7a43fa001640>})

# %%
y_pred = clf.predict(Xtest)
print(classification_report(ytest, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.43      0.53        21
#            1       0.67      0.48      0.56        21
#            2       0.62      0.58      0.60        26
#            3       0.73      0.71      0.72        34
#            4       0.86      0.91      0.89        34
#            5       0.84      0.62      0.71        26
#            6       1.00      0.73      0.84        22
#            7       0.74      1.00      0.85        28
#            8       0.93      0.79      0.85        33
#            9       0.91      0.84      0.88        25
#           10       0.90      0.96      0.93        27
#           11       0.68      0.95      0.79        20
#           12       0.56      0.62      0.59        24
#           13       0.79      0.65      0.71        23
#           14       0.87      0.71      0.78        28
#           15       0.47      0.93      0.62        29
#           16       0.43      0.95      0.60        21
#           17       0.94      0.89      0.91        18
#           18       0.88      0.27      0.41        26
#           19       0.00      0.00      0.00        14
#
#     accuracy                           0.72       500
#    macro avg       0.72      0.70      0.69       500
# weighted avg       0.75      0.72      0.71       500
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# #### Exercise
#
# 1. For the Naive Bayes model, use grid search 5-fold cross-validation across different values of `alpha` to find the best model.
#
# 2. For the best value of `alpha`, compute the `f1_macro` score on the test set.
# * What value of `alpha` did you obtain?
# * What is the model's `f1_macro` score?
#
# 3. Repeat Exercise 1 and 2 for **random search** 5-fold cross validation across different values of `alpha`. Compute the `f1_macro` score on the test set.
# * What value of `alpha` did you obtain?
# * Did you get a better `f1_macro` score compared to grid search in Exercise 2?

# %%
parameters = {'nb__alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]}
clf = GridSearchCV(pipline, parameters, cv=5,scoring='f1_macro')
clf.fit(Xtrain, ytrain)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('vect', TfidfVectorizer()),
#                                        ('nb', MultinomialNB())]),
#              param_grid={'nb__alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]},
#              scoring='f1_macro')

# %%
y_pred = clf.predict(Xtest)
print(classification_report(ytest, y_pred))
f1_macro_grid_search = f1_score(ytest, y_pred, average='macro')
print('f1 = ' ,f1_macro_grid_search)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.62      0.70        21
#            1       0.59      0.62      0.60        21
#            2       0.65      0.58      0.61        26
#            3       0.68      0.68      0.68        34
#            4       0.85      0.82      0.84        34
#            5       0.89      0.65      0.76        26
#            6       0.95      0.86      0.90        22
#            7       0.82      1.00      0.90        28
#            8       0.97      0.88      0.92        33
#            9       0.85      0.88      0.86        25
#           10       0.93      0.93      0.93        27
#           11       0.83      0.95      0.88        20
#           12       0.68      0.71      0.69        24
#           13       0.83      0.83      0.83        23
#           14       0.79      0.93      0.85        28
#           15       0.73      0.93      0.82        29
#           16       0.54      0.95      0.69        21
#           17       0.89      0.94      0.92        18
#           18       0.85      0.42      0.56        26
#           19       0.83      0.36      0.50        14
#
#     accuracy                           0.79       500
#    macro avg       0.80      0.78      0.77       500
# weighted avg       0.80      0.79      0.78       500
#
# f1 =  0.7725871193182322

# %%
parameters = {'nb__alpha': uniform(loc=0.01,scale = 10)}
clf = RandomizedSearchCV(pipline, parameters, cv=5,scoring='f1_macro')
clf.fit(Xtrain, ytrain)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('vect', TfidfVectorizer()),
#                                              ('nb', MultinomialNB())]),
#                    param_distributions={'nb__alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7a43f76cfe30>},
#                    scoring='f1_macro')

# %%
y_pred = clf.predict(Xtest)
print(classification_report(ytest, y_pred))
f1_macro_grid_search = f1_score(ytest, y_pred, average='macro')
print('f1 = ' ,f1_macro_grid_search)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.24      0.37        21
#            1       0.86      0.29      0.43        21
#            2       0.71      0.65      0.68        26
#            3       0.73      0.56      0.63        34
#            4       0.76      0.82      0.79        34
#            5       0.95      0.81      0.88        26
#            6       1.00      0.50      0.67        22
#            7       0.67      1.00      0.80        28
#            8       0.96      0.73      0.83        33
#            9       0.91      0.84      0.88        25
#           10       0.85      0.85      0.85        27
#           11       0.61      0.95      0.75        20
#           12       0.56      0.38      0.45        24
#           13       0.82      0.61      0.70        23
#           14       0.88      0.50      0.64        28
#           15       0.28      1.00      0.43        29
#           16       0.44      0.95      0.61        21
#           17       1.00      0.78      0.88        18
#           18       0.83      0.19      0.31        26
#           19       0.00      0.00      0.00        14
#
#     accuracy                           0.65       500
#    macro avg       0.73      0.63      0.63       500
# weighted avg       0.75      0.65      0.65       500
#
# f1 =  0.6277485177295925
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
